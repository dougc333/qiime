# %%
this is a qiime1 tutorial not qiime2!!! the commands dont exist.

# %%
https://nbviewer.jupyter.org/github/biocore/qiime/blob/1.9.1/examples/ipynb/illumina_overview_tutorial.ipynb

# %%
!(wget ftp://ftp.microbio.me/qiime/tutorial_files/moving_pictures_tutorial-1.9.0.tgz || curl -O ftp://ftp.microbio.me/qiime/tutorial_files/moving_pictures_tutorial-1.9.0.tgz)
# !tar -xzf moving_pictures_tutorial-1.9.0.tgz
# Out:
# --2020-04-08 16:25:18--  ftp://ftp.microbio.me/qiime/tutorial_files/moving_pictures_tutorial-1.9.0.tgz
#            => ‘moving_pictures_tutorial-1.9.0.tgz’
# Resolving ftp.microbio.me (ftp.microbio.me)... 169.228.46.98
# Connecting to ftp.microbio.me (ftp.microbio.me)|169.228.46.98|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /qiime/tutorial_files ... done.
# ==> SIZE moving_pictures_tutorial-1.9.0.tgz ... 77550824
# ==> PASV ... done.    ==> RETR moving_pictures_tutorial-1.9.0.tgz ... done.
# Length: 77550824 (74M) (unauthoritative)
#
# moving_pictures_tut 100%[===================>]  73.96M  10.7MB/s    in 7.6s
#
# 2020-04-08 16:25:26 (9.76 MB/s) - ‘moving_pictures_tutorial-1.9.0.tgz’ saved [77550824]

# %%
from IPython.display import FileLinks, FileLink

FileLinks('moving_pictures_tutorial-1.9.0')
# Out:
# moving_pictures_tutorial-1.9.0/
#   uc_fast_params.txt
#   README.txt
# moving_pictures_tutorial-1.9.0/454/raw/
#   454_map.txt
#   subsampled_454_seqs.fna
# moving_pictures_tutorial-1.9.0/illumina/
#   forward_reads.fastq.gz
#   map-bad.tsv
#   map.tsv
#   barcodes.fastq.gz
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/
#   table_even1114.biom
#   log_20150116193701.txt
#   index.html
#   group_significance_DaysSinceExperimentStart.txt
#   log_20150116192243.txt
#   table_even1114.biom.gz
#   table_mc1114.biom
#   group_significance_SampleType.txt
#   table_mc1114.biom.gz
#   biom_table_summary.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/arare_max1114/alpha_div_collated/
#   observed_otus.txt
#   PD_whole_tree.txt
#   chao1.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/arare_max1114/alpha_rarefaction_plots/
#   rarefaction_plots.html
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/arare_max1114/alpha_rarefaction_plots/average_plots/
#   PD_whole_treeBarcodeSequence.png
#   PD_whole_treeDaysSinceExperimentStart.png
#   chao1Subject.png
#   chao1Description.png
#   observed_otusYear.png
#   observed_otusDescription.png
#   PD_whole_treeSampleType.png
#   observed_otusLinkerPrimerSequence.png
#   chao1LinkerPrimerSequence.png
#   chao1BarcodeSequence.png
#   chao1Month.png
#   PD_whole_treeReportedAntibioticUsage.png
#   observed_otusDaysSinceExperimentStart.png
#   observed_otusSampleType.png
#   observed_otusMonth.png
#   chao1Year.png
#   chao1Day.png
#   PD_whole_treeLinkerPrimerSequence.png
#   observed_otusReportedAntibioticUsage.png
#   PD_whole_treeSubject.png
#   PD_whole_treeMonth.png
#   observed_otusSubject.png
#   observed_otusBarcodeSequence.png
#   PD_whole_treeSampleID.png
#   observed_otusSampleID.png
#   chao1SampleType.png
#   observed_otusDay.png
#   chao1DaysSinceExperimentStart.png
#   PD_whole_treeDay.png
#   chao1SampleID.png
#   chao1ReportedAntibioticUsage.png
#   PD_whole_treeYear.png
#   PD_whole_treeDescription.png
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/arare_max1114/compare_PD_whole_tree/
#   SampleType_stats.txt
#   DaysSinceExperimentStart_boxplots.pdf
#   DaysSinceExperimentStart_stats.txt
#   SampleType_boxplots.pdf
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/arare_max1114/compare_chao1/
#   SampleType_stats.txt
#   DaysSinceExperimentStart_boxplots.pdf
#   DaysSinceExperimentStart_stats.txt
#   SampleType_boxplots.pdf
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/arare_max1114/compare_observed_otus/
#   SampleType_stats.txt
#   DaysSinceExperimentStart_boxplots.pdf
#   DaysSinceExperimentStart_stats.txt
#   SampleType_boxplots.pdf
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/
#   weighted_unifrac_pc.txt
#   unweighted_unifrac_pc.txt
#   unweighted_unifrac_dm.txt
#   weighted_unifrac_dm.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_boxplots/
#   SampleType_Distances.pdf
#   SampleType_Stats.txt
#   DaysSinceExperimentStart_Stats.txt
#   DaysSinceExperimentStart_Distances.pdf
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/
#   index.html
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/emperor_required_resources/css/
#   chosen.min.css
#   jquery-ui2.css
#   colorPicker.css
#   d3.parcoords.css
#   spectrum.css
#   jquery-ui-1.8.16.custom.css
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/emperor_required_resources/css/images/
#   ui-icons_cd0a0a_256x240.png
#   ui-icons_888888_256x240.png
#   ui-bg_glass_75_dadada_1x400.png
#   ui-icons_2e83ff_256x240.png
#   ui-bg_flat_75_ffffff_40x100.png
#   ui-bg_glass_75_e6e6e6_1x400.png
#   ui-bg_glass_65_ffffff_1x400.png
#   ui-bg_glass_95_fef1ec_1x400.png
#   ui-icons_222222_256x240.png
#   ui-bg_highlight-soft_75_cccccc_1x100.png
#   ui-bg_glass_55_fbf9ee_1x400.png
#   ui-icons_454545_256x240.png
#   ui-bg_flat_0_aaaaaa_40x100.png
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/emperor_required_resources/emperor/css/
#   emperor.css
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/emperor_required_resources/emperor/js/
#   util.js
#   ui.js
#   trajectory.js
#   emperor.js
#   animate.js
#   draw.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/emperor_required_resources/img/
#   favicon.ico
#   reset.png
#   emperor.png
#   pause.png
#   play.png
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/emperor_required_resources/js/
#   FileSaver.min.js
#   jquery-1.6.2.min.js
#   three.min.js
#   jquery-ui-1.8.17.custom.min.js
#   d3.parcoords.js
#   underscore-min.js
#   chosen.jquery.min.js
#   THREEx.screenshot.js
#   jquery-1.7.1.min.js
#   d3.v3.min.js
#   spectrum.js
#   chroma.min.js
#   jquery.colorPicker.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/unweighted_unifrac_emperor_pcoa_plot/emperor_required_resources/js/js/
#   Detector.js
#   ColorConverter.js
#   OrbitControls.js
#   SVGRenderer.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_boxplots/
#   SampleType_Distances.pdf
#   SampleType_Stats.txt
#   DaysSinceExperimentStart_Stats.txt
#   DaysSinceExperimentStart_Distances.pdf
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/
#   index.html
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/emperor_required_resources/css/
#   chosen.min.css
#   jquery-ui2.css
#   colorPicker.css
#   d3.parcoords.css
#   spectrum.css
#   jquery-ui-1.8.16.custom.css
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/emperor_required_resources/css/images/
#   ui-icons_cd0a0a_256x240.png
#   ui-icons_888888_256x240.png
#   ui-bg_glass_75_dadada_1x400.png
#   ui-icons_2e83ff_256x240.png
#   ui-bg_flat_75_ffffff_40x100.png
#   ui-bg_glass_75_e6e6e6_1x400.png
#   ui-bg_glass_65_ffffff_1x400.png
#   ui-bg_glass_95_fef1ec_1x400.png
#   ui-icons_222222_256x240.png
#   ui-bg_highlight-soft_75_cccccc_1x100.png
#   ui-bg_glass_55_fbf9ee_1x400.png
#   ui-icons_454545_256x240.png
#   ui-bg_flat_0_aaaaaa_40x100.png
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/emperor_required_resources/emperor/css/
#   emperor.css
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/emperor_required_resources/emperor/js/
#   util.js
#   ui.js
#   trajectory.js
#   emperor.js
#   animate.js
#   draw.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/emperor_required_resources/img/
#   favicon.ico
#   reset.png
#   emperor.png
#   pause.png
#   play.png
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/emperor_required_resources/js/
#   FileSaver.min.js
#   jquery-1.6.2.min.js
#   three.min.js
#   jquery-ui-1.8.17.custom.min.js
#   d3.parcoords.js
#   underscore-min.js
#   chosen.jquery.min.js
#   THREEx.screenshot.js
#   jquery-1.7.1.min.js
#   d3.v3.min.js
#   spectrum.js
#   chroma.min.js
#   jquery.colorPicker.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/bdiv_even1114/weighted_unifrac_emperor_pcoa_plot/emperor_required_resources/js/js/
#   Detector.js
#   ColorConverter.js
#   OrbitControls.js
#   SVGRenderer.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots/
#   table_mc1114_sorted_L6.biom
#   table_mc1114_sorted_L3.biom
#   table_mc1114_sorted_L2.biom
#   table_mc1114_sorted_L5.biom
#   table_mc1114_sorted.biom
#   table_mc1114_sorted_L2.txt
#   table_mc1114_sorted_L3.txt
#   table_mc1114_sorted_L6.txt
#   table_mc1114_sorted_L4.biom
#   table_mc1114_sorted_L4.txt
#   table_mc1114_sorted_L5.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots/taxa_summary_plots/
#   bar_charts.html
#   area_charts.html
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots/taxa_summary_plots/charts/
#   tLmIUHneAKzQGz063dzdOkuaBDya0B.pdf
#   NiIH3PflpzQ0xrCPgMx2mwq6r7xcM5.png
#   ocs1Y2Jb3JtoyJ6fxkb6g09H2LkqNM.pdf
#   KIkl4qDZbrtKzzK7FCj1TDWU9xeWfj_legend.pdf
#   44wBb0LM5eCeoplBabwd6p020k41E1.png
#   BpbYlwNldgEEXLqAwFMGZZkqEpz3MH_legend.pdf
#   9DuMrJma6xieMzu6DoiWBzeT0UKBAR.png
#   KIkl4qDZbrtKzzK7FCj1TDWU9xeWfj.png
#   BpbYlwNldgEEXLqAwFMGZZkqEpz3MH.png
#   OlO9oy6b0xbkkTtpjZoO2fnLr1cHOq_legend.pdf
#   hsfqrSN0aBpQUFdjNmonrN20MDiAdT_legend.pdf
#   KXUIPiCiD8iWBmtWwS0gkwmtiSxCCz.pdf
#   o3zGZGuJj5xbcEe8dTeGKrrz0uLwNg_legend.pdf
#   9DuMrJma6xieMzu6DoiWBzeT0UKBAR_legend.pdf
#   60e6en9fxrDSkmbmZBXkpiMdQspzg5.pdf
#   PdGLUhTxHcXUIEBZE1YZbY4Tap5qBs_legend.pdf
#   44wBb0LM5eCeoplBabwd6p020k41E1_legend.pdf
#   PdGLUhTxHcXUIEBZE1YZbY4Tap5qBs.png
#   P7fDCGKmgPreJAyFgnotXxJnGEawKa_legend.pdf
#   P7fDCGKmgPreJAyFgnotXxJnGEawKa.png
#   NiIH3PflpzQ0xrCPgMx2mwq6r7xcM5_legend.pdf
#   OlO9oy6b0xbkkTtpjZoO2fnLr1cHOq.png
#   0lnpcYrNQlnmhpEjZrnmHZlkI0AL2s.pdf
#   1fLrUqlTEtOlZGaEkeSoIDwaKi0pin.pdf
#   TXABjauus6NudWxzm1mStZ5Feqhj3T.pdf
#   6h6OZ9sgQUP0gRJJPbZZtQ0ojHB5RF.pdf
#   hsfqrSN0aBpQUFdjNmonrN20MDiAdT.png
#   o3zGZGuJj5xbcEe8dTeGKrrz0uLwNg.png
#   OUuK0LJ6ZwCRTUqRczhLyX4zcoxfoz.pdf
#   wdfOyrTlmyL9c9lMZTcM93OtNZi12I.pdf
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots/taxa_summary_plots/css/
#   qiime_style.css
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots/taxa_summary_plots/js/
#   overlib.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots/taxa_summary_plots/raw_data/
#   table_mc1114_sorted_L2.txt
#   table_mc1114_sorted_L3.txt
#   table_mc1114_sorted_L6.txt
#   table_mc1114_sorted_L4.txt
#   table_mc1114_sorted_L5.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_DaysSinceExperimentStart/
#   DaysSinceExperimentStart_otu_table.biom
#   DaysSinceExperimentStart_otu_table_sorted.biom
#   DaysSinceExperimentStart_otu_table_sorted_L4.txt
#   DaysSinceExperimentStart_otu_table_sorted_L5.txt
#   DaysSinceExperimentStart_otu_table_sorted_L6.biom
#   DaysSinceExperimentStart_map.txt
#   DaysSinceExperimentStart_otu_table_sorted_L6.txt
#   DaysSinceExperimentStart_otu_table_sorted_L2.txt
#   DaysSinceExperimentStart_otu_table_sorted_L3.txt
#   DaysSinceExperimentStart_otu_table_sorted_L4.biom
#   DaysSinceExperimentStart_otu_table_sorted_L5.biom
#   DaysSinceExperimentStart_otu_table_sorted_L2.biom
#   DaysSinceExperimentStart_otu_table_sorted_L3.biom
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_DaysSinceExperimentStart/taxa_summary_plots/
#   bar_charts.html
#   area_charts.html
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_DaysSinceExperimentStart/taxa_summary_plots/charts/
#   wEHZZcliFlaJpbX0nKhI00zTwKOG9J_legend.pdf
#   K2gYb5KATZN6pnazU7E4X92cyu2C3w.png
#   spgaDLeMxuOfx81oT7rHEwaAe6lPoR.png
#   gdPC8od9NROtq01Cf4x8Tn2IhzayUP.pdf
#   uMz8N2kiIMN8YhUSo60Y0BK65BJ4pD.png
#   35qKlMsKcoAYX7lnGYB949tKNhdbmy_legend.pdf
#   ugzQc00hGAxsQHOD8kZ2ZI2mzzUZN8.pdf
#   Mj8anZoNHiDrqZQZ7owsYzpYCo81ba_legend.pdf
#   uMz8N2kiIMN8YhUSo60Y0BK65BJ4pD_legend.pdf
#   NP0KBAgc3z7jwe0KN0fUdZEnamuPQm.pdf
#   Mj8anZoNHiDrqZQZ7owsYzpYCo81ba.png
#   B0FzPf6eFw6WPzZJJGq0zWDyLLe31O.pdf
#   sAD6CJfhCLXwCUk2mSagldWIQ6wQrl.pdf
#   MHHbEPJjAJ8l980rtw8GAhd5EBnwoc.pdf
#   wEHZZcliFlaJpbX0nKhI00zTwKOG9J.png
#   lqmPZWONHP6CexmrRotMXoX8woUYDg.png
#   spgaDLeMxuOfx81oT7rHEwaAe6lPoR_legend.pdf
#   EQRtxrKzqj9S7n1ONPwrrhfCo6bx9Z.pdf
#   j5bmxLtutnyL0C5kETH08o4Mb6DXUk.pdf
#   K2gYb5KATZN6pnazU7E4X92cyu2C3w_legend.pdf
#   qh53SBO0Q7pCF2fMAOMfMzert35NbL.pdf
#   lqmPZWONHP6CexmrRotMXoX8woUYDg_legend.pdf
#   J0wF4O0gOAAzFhmQqfi2DqyrNKZsM0.png
#   35qKlMsKcoAYX7lnGYB949tKNhdbmy.png
#   rlH6Zj0CdppgC2fB8B5m3cRWyJ3Ifu.png
#   p3zRW9cW2qC98ljNxaKIQyqXND0eHm.png
#   J0wF4O0gOAAzFhmQqfi2DqyrNKZsM0_legend.pdf
#   p3zRW9cW2qC98ljNxaKIQyqXND0eHm_legend.pdf
#   rlH6Zj0CdppgC2fB8B5m3cRWyJ3Ifu_legend.pdf
#   H2wL1kM0ZtXgSxjk8sOtS6XsGSx5cZ.pdf
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_DaysSinceExperimentStart/taxa_summary_plots/css/
#   qiime_style.css
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_DaysSinceExperimentStart/taxa_summary_plots/js/
#   overlib.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_DaysSinceExperimentStart/taxa_summary_plots/raw_data/
#   DaysSinceExperimentStart_otu_table_sorted_L4.txt
#   DaysSinceExperimentStart_otu_table_sorted_L5.txt
#   DaysSinceExperimentStart_otu_table_sorted_L6.txt
#   DaysSinceExperimentStart_otu_table_sorted_L2.txt
#   DaysSinceExperimentStart_otu_table_sorted_L3.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_SampleType/
#   SampleType_otu_table_sorted.biom
#   SampleType_otu_table_sorted_L6.biom
#   SampleType_otu_table_sorted_L5.biom
#   SampleType_otu_table_sorted_L4.biom
#   SampleType_otu_table_sorted_L3.txt
#   SampleType_otu_table_sorted_L3.biom
#   SampleType_otu_table_sorted_L2.txt
#   SampleType_otu_table.biom
#   SampleType_otu_table_sorted_L6.txt
#   SampleType_otu_table_sorted_L2.biom
#   SampleType_otu_table_sorted_L5.txt
#   SampleType_otu_table_sorted_L4.txt
#   SampleType_map.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_SampleType/taxa_summary_plots/
#   bar_charts.html
#   area_charts.html
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_SampleType/taxa_summary_plots/charts/
#   gZt1IMPidAqikXqpFYgwr0e29ZO7MU_legend.pdf
#   m64BZa8hjeftmU066zrqSmZ0ckwzut_legend.pdf
#   Ra8yWW2YOK2tZyH5cWXKX36xw1o19M_legend.pdf
#   y5edCREBofl8ZmBj8Mdl9tIL2oBFMg_legend.pdf
#   XAqypW0DAGzcQzRmxxmeQuiBIQ3kLc.pdf
#   Tn038OZyXdx3tM8xhKBfwwuK2QFQTY.pdf
#   CXZA2bR5zl6puL26zKMhYibD4HFJd0.pdf
#   fsC2w3wWtg6ZeqG3w734imDGL4zoLB.pdf
#   Z86Zapy0cT5s0koXPseYxcgz2orrmd_legend.pdf
#   dPjLYYlMKLboLTKhGKQX8XBjw7I1zz.png
#   y5edCREBofl8ZmBj8Mdl9tIL2oBFMg.png
#   QOlY04E7H5bKoErZJT9Za6c9M2JnIj_legend.pdf
#   QOlY04E7H5bKoErZJT9Za6c9M2JnIj.png
#   J7kE6Zih0f2uIxYZN2GDu5SZGM5ciz.png
#   CqbtJAHwyqzYOuXabpLnONmb0LjFbx.pdf
#   J7kE6Zih0f2uIxYZN2GDu5SZGM5ciz_legend.pdf
#   cO62iMyoEuLK7eX62yZCld15jsN8An.pdf
#   Ra8yWW2YOK2tZyH5cWXKX36xw1o19M.png
#   NCTg45IOHnfEZy8JSCbJctxcNyNxJd.png
#   gZt1IMPidAqikXqpFYgwr0e29ZO7MU.png
#   RNBjnzHc3NRw9aph7yAxZZIFOz3zZU.pdf
#   bu5Tr6YDz5efnBX6xg7qJhPKgezBpM.pdf
#   m64BZa8hjeftmU066zrqSmZ0ckwzut.png
#   0gRhS9L0mADfGfZsyze05Zfdo20R0A_legend.pdf
#   dPjLYYlMKLboLTKhGKQX8XBjw7I1zz_legend.pdf
#   c3JzfmUfAzHcKersoddS86S829J7qq.pdf
#   NCTg45IOHnfEZy8JSCbJctxcNyNxJd_legend.pdf
#   wz66ZMpy99bEz7ILSmfzzZdbyDpYWS.pdf
#   Z86Zapy0cT5s0koXPseYxcgz2orrmd.png
#   0gRhS9L0mADfGfZsyze05Zfdo20R0A.png
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_SampleType/taxa_summary_plots/css/
#   qiime_style.css
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_SampleType/taxa_summary_plots/js/
#   overlib.js
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/cdout/taxa_plots_SampleType/taxa_summary_plots/raw_data/
#   SampleType_otu_table_sorted_L3.txt
#   SampleType_otu_table_sorted_L2.txt
#   SampleType_otu_table_sorted_L6.txt
#   SampleType_otu_table_sorted_L5.txt
#   SampleType_otu_table_sorted_L4.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/otus/
#   final_otu_map.txt
#   rep_set.tre
#   index.html
#   final_otu_map_mc2.txt
#   otu_table_mc2_w_tax_no_pynast_failures.biom
#   otu_table_mc2.biom
#   log_20150116191009.txt
#   otu_table_mc2_w_tax.biom
#   new_refseqs.fna
#   rep_set.fna
#   otu_table_mc2_w_tax_no_pynast_failures_summary.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/otus/pynast_aligned_seqs/
#   rep_set_aligned_pfiltered.fasta
#   rep_set_aligned.fasta
#   rep_set_log.txt
#   rep_set_failures.fasta
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/otus/step1_otus/
#   seqs_otus.txt
#   seqs_clusters.uc
#   step1_rep_set.fna
#   failures.fasta
#   seqs_otus.log
#   seqs_failures.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/otus/step4_otus/
#   failures_otus.log
#   failures_clusters.uc
#   step4_rep_set.fna
#   failures_otus.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/otus/uclust_assigned_taxonomy/
#   rep_set_tax_assignments.log
#   rep_set_tax_assignments.txt
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/slout/
#   split_library_log.txt
#   histograms.txt
#   seqs.fna
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/vmf-map/
#   overlib.js
#   map.tsv_corrected.txt
#   map.tsv.html
#   map.tsv.log
# moving_pictures_tutorial-1.9.0/illumina/precomputed-output/vmf-map-bad/
#   map-bad.tsv.log
#   map-bad.tsv.html
#   overlib.js
#   map-bad.tsv_corrected.txt
# moving_pictures_tutorial-1.9.0/procrustes_analysis/
#   procrustes_metadata_map.txt
#   procrustes_sid_map.txt

# %%
FileLink('moving_pictures_tutorial-1.9.0/README.txt')
# Out:
# /Users/dougchang/qiime/moving_pictures_tutorial-1.9.0/README.txt

# %%
from functools import partial
import os
from os import chdir
print(os.getcwd())
#chdir('moving_pictures_tutorial-1.9.0/illumina')
FileLink = partial(FileLink, url_prefix='moving_pictures_tutorial-1.9.0/illumina/')
FileLinks = partial(FileLinks, url_prefix='moving_pictures_tutorial-1.9.0/illumina/')
# Out:
# /Users/dougchang/qiime/moving_pictures_tutorial-1.9.0/illumina
